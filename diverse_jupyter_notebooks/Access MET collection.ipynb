# %% [markdown]
# # Access the MET collection via API
# ### for the Cultural Data Sculpting course at EPFL

# %%
import urllib.request, urllib.error, urllib.parse
import csv
from bs4 import BeautifulSoup
import html2text
import os
from datetime import datetime
import numpy as np
import pandas as pd
import json
from urllib.request import urlopen
from PIL import Image

# %%
# function to check if 'nan'

def isnan(x):
    return x != x

# %%
filename = 'artist_qid.csv'
csv_file = csv.reader(open(filename, "r"))
df = pd.read_csv(filename)
#df

# %% [markdown]
# ## TO DO
#
# - DONE!! load the object csv file and retrieve all the relevant Object ID
# - DONE! call for all the object to get the URLs
# - Download Images
# - name them properly for cables implementation

# %% [markdown]
# ### load MET Objects.csv with all the objects of the MET collection

# %%
filename = 'MetObjects.csv'
csv_file = csv.reader(open(filename, "r"))
MET = pd.read_csv(filename,  low_memory=False)

# %%
MET
# Out:
#        Object Number  Is Highlight  Is Timeline Work  Is Public Domain  \
# 0         1979.486.1         False             False             False
# 1         1980.264.5         False             False             False
# 2           67.265.9         False             False             False
# 3          67.265.10         False             False             False
# 4          67.265.11         False             False             False
# ...              ...           ...               ...               ...
# 475772    2021.60.10         False             False             False
# 475773      83.2.934         False             False             False
# 475774      83.2.936         False             False             False
# 475775   1984.1188.1         False             False             False
# 475776   1976.661(8)         False             False             False
#
#         Object ID Gallery Number           Department AccessionYear  \
# 0               1            NaN    The American Wing          1979
# 1               2            NaN    The American Wing          1980
# 2               3            NaN    The American Wing          1967
# 3               4            NaN    The American Wing          1967
# 4               5            NaN    The American Wing          1967
# ...           ...            ...                  ...           ...
# 475772     852903            NaN  Drawings and Prints           NaN
# 475773     852913            NaN  Drawings and Prints           NaN
# 475774     852915            NaN  Drawings and Prints           NaN
# 475775     852928            NaN  Drawings and Prints           NaN
# 475776     852956            NaN  Drawings and Prints          1976
#
#        Object Name                                 Title  ... River  \
# 0             Coin          One-dollar Liberty Head Coin  ...   NaN
# 1             Coin          Ten-dollar Liberty Head Coin  ...   NaN
# 2             Coin            Two-and-a-Half Dollar Coin  ...   NaN
# 3             Coin            Two-and-a-Half Dollar Coin  ...   NaN
# 4             Coin            Two-and-a-Half Dollar Coin  ...   NaN
# ...            ...                                   ...  ...   ...
# 475772      Poster  Black Women’s Wisdom: Amelia Boynton  ...   NaN
# 475773       Print    Toussaint L’Ouverture on Horseback  ...   NaN
# 475774       Print    Toussaint L’Ouverture on Horseback  ...   NaN
# 475775       Print         Composition in Black and Blue  ...   NaN
# 475776   Portfolio                              Untitled  ...   NaN
#
#        Classification Rights and Reproduction  \
# 0                 NaN                     NaN
# 1                 NaN                     NaN
# 2                 NaN                     NaN
# 3                 NaN                     NaN
# 4                 NaN                     NaN
# ...               ...                     ...
# 475772        Posters                     NaN
# 475773         Prints                     NaN
# 475774         Prints                     NaN
# 475775         Prints                     NaN
# 475776     Portfolios                     NaN
#
#                                             Link Resource Object Wikidata URL  \
# 0        http://www.metmuseum.org/art/collection/search/1                 NaN
# 1        http://www.metmuseum.org/art/collection/search/2                 NaN
# 2        http://www.metmuseum.org/art/collection/search/3                 NaN
# 3        http://www.metmuseum.org/art/collection/search/4                 NaN
# 4        http://www.metmuseum.org/art/collection/search/5                 NaN
# ...                                                   ...                 ...
# 475772  http://www.metmuseum.org/art/collection/search...                 NaN
# 475773  http://www.metmuseum.org/art/collection/search...                 NaN
# 475774  http://www.metmuseum.org/art/collection/search...                 NaN
# 475775  http://www.metmuseum.org/art/collection/search...                 NaN
# 475776  http://www.metmuseum.org/art/collection/search...                 NaN
#
#        Metadata Date                                Repository           Tags  \
# 0                NaN  Metropolitan Museum of Art, New York, NY            NaN
# 1                NaN  Metropolitan Museum of Art, New York, NY            NaN
# 2                NaN  Metropolitan Museum of Art, New York, NY            NaN
# 3                NaN  Metropolitan Museum of Art, New York, NY            NaN
# 4                NaN  Metropolitan Museum of Art, New York, NY            NaN
# ...              ...                                       ...            ...
# 475772           NaN  Metropolitan Museum of Art, New York, NY            NaN
# 475773           NaN  Metropolitan Museum of Art, New York, NY            NaN
# 475774           NaN  Metropolitan Museum of Art, New York, NY            NaN
# 475775           NaN  Metropolitan Museum of Art, New York, NY            NaN
# 475776           NaN  Metropolitan Museum of Art, New York, NY  Men|Portraits
#
#                                              Tags AAT URL  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 475772                                                NaN
# 475773                                                NaN
# 475774                                                NaN
# 475775                                                NaN
# 475776  http://vocab.getty.edu/page/aat/300025928|http...
#
#                                         Tags Wikidata URL
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 475772                                                NaN
# 475773                                                NaN
# 475774                                                NaN
# 475775                                                NaN
# 475776  https://www.wikidata.org/wiki/Q8441|https://ww...
#
# [475777 rows x 54 columns]

# %% [markdown]
# ### get the column MET['Artist Wikidata URL'] to compare with Vasari Dataframe

# %%
# try and test
MET_urlist = np.array(MET['Artist Wikidata URL']) 
MET_urlist[475726].strip('|').split('|')[0]
# Out:
# 'https://www.wikidata.org/wiki/Q214957'

# %%
# prepare MET artist wikidata list:
liste = []
for i in MET_urlist:
    if isnan(i):
        liste.append('nan')
    else:
        liste.append(i.strip('|').split('|')[0]) 
    
liste[3555]
# Out:
# 'https://www.wikidata.org/wiki/Q3041258'

# %%
# prepare df for MET artist wikidata list
wikidata = []
for i in df['Wikidata-Q-ID']:
    wikidata.append('https://www.wikidata.org/wiki/' + str(i))

df['wikidata'] = wikidata    
#df

# %% [markdown]
# ## if the Wikidata artist URL is in the MET Object list, store the index of the object

# %%
liste = []
for i in df['wikidata']:
    if i in MET_urlist:
        liste.append(np.where(MET_urlist == i)[0])
    else:
        liste.append('nan')
df['MET Object Indices'] = liste
#df

# %% [markdown]
# ### get the MET Object IDs for the artworks

# %%
# process indices to real MET Object IDs

liste = []
for i in df['MET Object Indices']:
    if i == 'nan':
        liste.append('nan')
    else:
        storage = []
        for j in i:
            storage.append(MET.iloc[j]['Object ID'])
        liste.append(storage)
            
df['REAL MET Object IDS'] = liste
#df
# Out:
# <ipython-input-14-ef4217cdccb2>:5: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if i == 'nan':

# %% [markdown]
# ## save as csv

# %%
df
# Out:
#                                        Name Wikidata-Q-ID  \
# 0                                   Cimabue        Q15790
# 1                           Arnolfo di Lapo       Q315249
# 2                                   Bonanno       Q892084
# 3                             Nicola Pisano       Q364413
# 4                           Giovanni Pisano       Q314932
# ..                                      ...           ...
# 287                               Dono Doni       Q714914
# 288                           Cesare Nebbia       Q503575
# 289  Niccolò Circignani detto il Pomarancio       Q382762
# 290                                Bronzino         Q7803
# 291                          Giorgio Vasari       Q128027
#
#                                          Wikipedia-URL  \
# 0                https://en.wikipedia.org/wiki/Cimabue
# 1      https://en.wikipedia.org/wiki/Arnolfo_di_Cambio
# 2         https://en.wikipedia.org/wiki/Bonanno_Pisano
# 3          https://en.wikipedia.org/wiki/Nicola_Pisano
# 4        https://en.wikipedia.org/wiki/Giovanni_Pisano
# ..                                                 ...
# 287            https://en.wikipedia.org/wiki/Dono_Doni
# 288        https://en.wikipedia.org/wiki/Cesare_Nebbia
# 289  https://en.wikipedia.org/wiki/Niccol%C3%B2_Cir...
# 290             https://en.wikipedia.org/wiki/Bronzino
# 291       https://en.wikipedia.org/wiki/Giorgio_Vasari
#
#                    URL-names  \
# 0                    Cimabue
# 1          Arnolfo_di_Cambio
# 2             Bonanno_Pisano
# 3              Nicola_Pisano
# 4            Giovanni_Pisano
# ..                       ...
# 287                Dono_Doni
# 288            Cesare_Nebbia
# 289  Niccol%C3%B2_Circignani
# 290                 Bronzino
# 291           Giorgio_Vasari
#
#                                                Summary  \
# 0    Cimabue, also known as Cenni di Pepo or Cenni ...
# 1    Arnolfo di Cambio was an Italian architect and...
# 2    Bonanno Pisano (Pisa), active in the 1170s and...
# 3    Nicola Pisano was an Italian sculptor whose wo...
# 4    Giovanni Pisano was an Italian sculptor, paint...
# ..                                                 ...
# 287  Dono Doni, also known as Adone Doni or Dono de...
# 288  Cesare Nebbia (c.1536–c.1622) was an Italian p...
# 289  Niccolò Circignani was an Italian painter of t...
# 290  Agnolo di Cosimo, usually known as Bronzino or...
# 291  Giorgio Vasari was an Italian painter, archite...
#
#                                         Wikipedia-json  \
# 0    {'type': 'standard', 'title': 'Cimabue', 'disp...
# 1    {'type': 'standard', 'title': 'Arnolfo di Camb...
# 2    {'type': 'standard', 'title': 'Bonanno Pisano'...
# 3    {'type': 'standard', 'title': 'Nicola Pisano',...
# 4    {'type': 'standard', 'title': 'Giovanni Pisano...
# ..                                                 ...
# 287  {'type': 'standard', 'title': 'Dono Doni', 'di...
# 288  {'type': 'standard', 'title': 'Cesare Nebbia',...
# 289  {'type': 'standard', 'title': 'Niccolò Circign...
# 290  {'type': 'standard', 'title': 'Bronzino', 'dis...
# 291  {'type': 'standard', 'title': 'Giorgio Vasari'...
#
#                                                  image  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 287  https://upload.wikimedia.org/wikipedia/commons...
# 288  https://upload.wikimedia.org/wikipedia/commons...
# 289  https://upload.wikimedia.org/wikipedia/commons...
# 290  https://upload.wikimedia.org/wikipedia/commons...
# 291  https://upload.wikimedia.org/wikipedia/commons...
#
#                                              thumbnail  birth  death  \
# 0    https://upload.wikimedia.org/wikipedia/commons...   1240   1302
# 1    https://upload.wikimedia.org/wikipedia/commons...   1240   1302
# 2    https://upload.wikimedia.org/wikipedia/commons...   9999   9999
# 3    https://upload.wikimedia.org/wikipedia/commons...   1225   1284
# 4    https://upload.wikimedia.org/wikipedia/commons...   1248   1316
# ..                                                 ...    ...    ...
# 287  https://upload.wikimedia.org/wikipedia/commons...   1500   1575
# 288  https://upload.wikimedia.org/wikipedia/commons...   1536   1614
# 289  https://upload.wikimedia.org/wikipedia/commons...   1517   1597
# 290  https://upload.wikimedia.org/wikipedia/commons...   1503   1572
# 291  https://upload.wikimedia.org/wikipedia/commons...   1511   1574
#
#      timeline_position       VIAF                               wikidata  \
# 0                 1271   11146779   https://www.wikidata.org/wiki/Q15790
# 1                 1271  265308757  https://www.wikidata.org/wiki/Q315249
# 2                 9999   95743493  https://www.wikidata.org/wiki/Q892084
# 3                 1254   79399625  https://www.wikidata.org/wiki/Q364413
# 4                 1282  100174152  https://www.wikidata.org/wiki/Q314932
# ..                 ...        ...                                    ...
# 287               1538   74702895  https://www.wikidata.org/wiki/Q714914
# 288               1575   13152008  https://www.wikidata.org/wiki/Q503575
# 289               1557   95809921  https://www.wikidata.org/wiki/Q382762
# 290               1538   59354048    https://www.wikidata.org/wiki/Q7803
# 291               1542   46768219  https://www.wikidata.org/wiki/Q128027
#
#                                     MET Object Indices  \
# 0                                                  nan
# 1                                                  nan
# 2                                                  nan
# 3                                                  nan
# 4                     [313456, 313457, 315423, 315800]
# ..                                                 ...
# 287                                                nan
# 288  [209395, 209639, 209640, 209658, 209659, 21035...
# 289                                           [211022]
# 290   [213792, 238232, 239821, 295526, 295527, 376242]
# 291                                                nan
#
#                                    REAL MET Object IDS
# 0                                                  nan
# 1                                                  nan
# 2                                                  nan
# 3                                                  nan
# 4                     [463414, 463415, 465937, 466326]
# ..                                                 ...
# 287                                                nan
# 288  [340591, 340835, 340836, 340854, 340855, 34157...
# 289                                           [342245]
# 290   [345085, 370424, 372062, 435802, 435803, 643060]
# 291                                                nan
#
# [292 rows x 15 columns]

# %%
df.to_csv('artist_qid.csv', index = False, header=True)

# %% [markdown]
# ## get all the image URLs from MET API

# %%
# make list of image URLs per artist

index = 0
liste = []

for i in range(len(df)):
    
    if df['REAL MET Object IDS'][i] == 'nan':
        storage = ['nan']
        liste.append(storage)
    else:
        
        storage = []
        for j in df['REAL MET Object IDS'][i]:
            
            url = 'https://collectionapi.metmuseum.org/public/collection/v1/objects/' + str(j)
            response = urllib.request.urlopen(url) 
            webContent = response.read()
            my_json = webContent.decode('utf8')
            data = json.loads(my_json)
            storage.append(data['primaryImageSmall'])
        
    
        liste.append(storage)
    
    
    print(storage, index)
    index += 1
    
len(liste) 
df['URL-Liste-small'] = liste
# Out:
# ['nan'] 0
# ['nan'] 1
# ['nan'] 2
# ['nan'] 3
# ['https://images.metmuseum.org/CRDImages/md/web-large/DP169508.jpg', 'https://images.metmuseum.org/CRDImages/md/web-large/DP169512.jpg', 'https://images.metmuseum.org/CRDImages/md/web-large/DP167328.jpg', 'https://images.metmuseum.org/CRDImages/md/web-large/DP169524.jpg'] 4
# ['nan'] 5
# ['nan'] 6
# ['nan'] 7
# ['https://images.metmuseum.org/CRDImages/ep/web-large/DP-19501-001.jpg'] 8
# ['nan'] 9
# ['nan'] 10
# ['nan'] 11
# ['nan'] 12
# ['https://images.metmuseum.org/CRDImages/ep/web-large/DP296426.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DT3002.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DP-18967-001.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DT3003.jpg'] 13
# ['https://images.metmuseum.org/CRDImages/ep/web-large/SF Lorenzetti.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP278472.jpg'] 14
# ['nan'] 15
# ['nan'] 16
# ['https://images.metmuseum.org/CRDImages/ep/web-large/ep41.190.26.bw.R.jpg'] 17
# ['nan'] 18
# ['https://images.metmuseum.org/CRDImages/ep/web-large/DP343101.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP168806.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP-12431-001.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP168805.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP168803.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DT3006.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DT704.jpg'] 19
# ['https://images.metmuseum.org/CRDImages/ep/web-large/DP367960.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DT301036.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP295031.jpg'] 20
# ['https://images.metmuseum.org/CRDImages/ep/web-large/EP327.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DT4166.jpg'] 21
# ['https://images.metmuseum.org/CRDImages/rl/web-large/DT3046.jpg'] 22
# ['nan'] 23
# ['nan'] 24
# ['https://images.metmuseum.org/CRDImages/ep/web-large/EP264.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/SF Gaddi.jpg'] 25
# ['nan'] 26
# ['https://images.metmuseum.org/CRDImages/rl/web-large/LC-1975_1_010_001.jpg'] 27
# ['https://images.metmuseum.org/CRDImages/ep/web-large/DP142735.jpg'] 28
# ['nan'] 29
# ['nan'] 30
# ['https://images.metmuseum.org/CRDImages/ep/web-large/DP296527.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DT3044.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DT3045.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DP318243.jpg'] 31
# ['nan'] 32
# ['https://images.metmuseum.org/CRDImages/ep/web-large/DP367960.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DT301036.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP295031.jpg'] 33
# ['https://images.metmuseum.org/CRDImages/dp/web-large/DP812344.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP-19549-001.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP-19552-001.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP-19551-001.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP-19550-001.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DT709.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DT3047.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DP358989.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DT3620.jpg', 'https://images.metmuseum.org/CRDImages/cl/web-large/DP359505.jpg'] 34
# ['https://images.metmuseum.org/CRDImages/ep/web-large/DP278476.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DP293274.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DP293275.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DP293276.jpg'] 35
# ['nan'] 36
# ['https://images.metmuseum.org/CRDImages/ep/web-large/DT273088.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DT273089.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DT3048.jpg'] 37
# ['https://images.metmuseum.org/CRDImages/rl/web-large/DP318247.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DP328373.jpg'] 38
# ['https://images.metmuseum.org/CRDImages/dp/web-large/DP102195.jpg'] 39
# ['nan'] 40
# ['nan'] 41
# ['nan'] 42
# ['https://images.metmuseum.org/CRDImages/es/web-large/DP-16188-001.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP225831.jpg'] 43
# ['https://images.metmuseum.org/CRDImages/es/web-large/11523.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/11524.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP-15823-001.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/120116.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/ES7896.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP369834.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DT254658.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/197109.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP-17649-001.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/ES4933_X.102.jpg'] 44
# ['nan'] 45
# ['https://images.metmuseum.org/CRDImages/ep/web-large/DT4172.jpg'] 46
# ['https://images.metmuseum.org/CRDImages/es/web-large/1890.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/3681.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/183880.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP233268.jpg'] 47
# ['nan'] 48
# ['nan'] 49
# ['nan'] 50
# ['nan'] 51
# ['nan'] 52
# ['https://images.metmuseum.org/CRDImages/es/web-large/LC-73_8_31.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/ep07.225.251b.bw.R.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/6651.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/ES5236.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/171480.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP-159-001.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/49753.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP242101.jpg', ''] 53
# ['nan'] 54
# ['nan'] 55
# ['https://images.metmuseum.org/CRDImages/es/web-large/DP167099.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/SF-1975-1-1270obv.jpg'] 56
# ['nan'] 57
# ['nan'] 58
# ['nan'] 59
# ['https://images.metmuseum.org/CRDImages/ep/web-large/DP-19582-001.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP-20398-001.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP-18360-001.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DP358976.jpg'] 60
# ['nan'] 61
# ['nan'] 62
# ['nan'] 63
# ['nan'] 64
# ['https://images.metmuseum.org/CRDImages/ep/web-large/DT285189.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP120669.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DP358978.jpg'] 65
# ['nan'] 66
# ['https://images.metmuseum.org/CRDImages/es/web-large/DP224290.jpg'] 67
# ['https://images.metmuseum.org/CRDImages/ep/web-large/DP-20746-001.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/D
jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP811852.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DT5147.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP-17398-001.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DT2774.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP-19299-001.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DT11.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DT226035.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/ep32.100.85.bw.R.jpg', '', ''] 270
# ['https://images.metmuseum.org/CRDImages/dp/web-large/DP807847.jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP807848.jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP807850.jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP801271.jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP807849.jpg', ''] 271
# ['nan'] 272
# ['https://images.metmuseum.org/CRDImages/dp/web-large/DP853465.jpg', '', '', '', '', '', '', ''] 273
# ['https://images.metmuseum.org/CRDImages/ep/web-large/DP-17629-001.jpg'] 274
# ['https://images.metmuseum.org/CRDImages/es/web-large/SF83_18_281.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/SF83_18_286.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP-70-0001.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP-71-0001.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP-18299-001.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/116669.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/SF-1975-1-1329.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/SF-1975-1-1351.jpg'] 275
# [''] 276
# ['https://images.metmuseum.org/CRDImages/es/web-large/ES7584.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP-1366-001.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP217259.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP-1234-001.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/160496.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/174103.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP-42-001.jpg'] 277
# ['https://images.metmuseum.org/CRDImages/dp/web-large/DP807710.jpg'] 278
# ['https://images.metmuseum.org/CRDImages/es/web-large/SF73_8_66.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP147770.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP-1235-001.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP-1236-001.jpg'] 279
# ['https://images.metmuseum.org/CRDImages/es/web-large/39650.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/55368.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/61784.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/82261.jpg', '', 'https://images.metmuseum.org/CRDImages/es/web-large/108977.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/109160.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP273901.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP155287.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP-15401-067.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/1278r-1.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/1277.jpg'] 280
# ['https://images.metmuseum.org/CRDImages/es/web-large/16661.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/16660.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP-12188-001.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/62664.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DT255085.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DT318845.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/171271.jpg', 'https://images.metmuseum.org/CRDImages/es/web-large/DP-17076-001.jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP811268.jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP811266.jpg', 'https://images.metmuseum.org/CRDImages/rl/web-large/DP-19531-059.jpg'] 281
# ['https://images.metmuseum.org/CRDImages/dp/web-large/DP807547.jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP807557.jpg'] 282
# [''] 283
# ['nan'] 284
# ['https://images.metmuseum.org/CRDImages/dp/web-large/DP811745.jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP811750.jpg'] 285
# ['nan'] 286
# ['nan'] 287
# ['https://images.metmuseum.org/CRDImages/dp/web-large/DP810919.jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP810917.jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP810910.jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP810912.jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP810918.jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP820499.jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP801772.jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP810915.jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP854927.jpg'] 288
# ['https://images.metmuseum.org/CRDImages/dp/web-large/DP809178.jpg'] 289
# ['https://images.metmuseum.org/CRDImages/dp/web-large/DP808035.jpg', '', '', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP-14286-011.jpg', 'https://images.metmuseum.org/CRDImages/ep/web-large/DP104985.jpg', 'https://images.metmuseum.org/CRDImages/dp/web-large/DP838058.jpg'] 290
# ['nan'] 291

# %%
# make new DataFrame with reduced columns

new_df = pd.DataFrame()
new_df["URL-Liste"] = df["URL-Liste"]
new_df["Name"] = df["Name"]
new_df["URL-names"] = df["URL-names"]
new_df["timeline_position"] = df["timeline_position"]
new_df['URL-Liste-small'] = liste

new_df
# Out:
#                                              URL-Liste  \
# 0                                                [nan]
# 1                                                [nan]
# 2                                                [nan]
# 3                                                [nan]
# 4    [https://images.metmuseum.org/CRDImages/md/ori...
# ..                                                 ...
# 287                                              [nan]
# 288  [https://images.metmuseum.org/CRDImages/dp/ori...
# 289  [https://images.metmuseum.org/CRDImages/dp/ori...
# 290  [https://images.metmuseum.org/CRDImages/dp/ori...
# 291                                              [nan]
#
#                                        Name                URL-names  \
# 0                                   Cimabue                  Cimabue
# 1                           Arnolfo di Lapo        Arnolfo_di_Cambio
# 2                                   Bonanno           Bonanno_Pisano
# 3                             Nicola Pisano            Nicola_Pisano
# 4                           Giovanni Pisano          Giovanni_Pisano
# ..                                      ...                      ...
# 287                               Dono Doni                Dono_Doni
# 288                           Cesare Nebbia            Cesare_Nebbia
# 289  Niccolò Circignani detto il Pomarancio  Niccol%C3%B2_Circignani
# 290                                Bronzino                 Bronzino
# 291                          Giorgio Vasari           Giorgio_Vasari
#
#      timeline_position                                    URL-Liste-small
# 0                 1271                                              [nan]
# 1                 1271                                              [nan]
# 2                 9999                                              [nan]
# 3                 1254                                              [nan]
# 4                 1282  [https://images.metmuseum.org/CRDImages/md/web...
# ..                 ...                                                ...
# 287               1538                                              [nan]
# 288               1575  [https://images.metmuseum.org/CRDImages/dp/web...
# 289               1557  [https://images.metmuseum.org/CRDImages/dp/web...
# 290               1538  [https://images.metmuseum.org/CRDImages/dp/web...
# 291               1542                                              [nan]
#
# [292 rows x 5 columns]

# %% [markdown]
# ### function to open an image-url and return it in squared format

# %%
# function to open url and return it in squared format 

def getsquared_image(url):
    # open image-url, get width, height
    img = Image.open(urlopen(url))
    width, height = img.size
    # store the bigger one in s
    if width < height:
        s = height
    else:
        s = width
    
    # create empty opaque image file and paste picture
    new_img = Image.new('RGBA', (s,s), (255, 0, 0, 0))
    new_img.paste(img, (s-width, 0))
    
    return new_img

# %%
img = getsquared_image('https://images.metmuseum.org/CRDImages/md/web-large/DP169508.jpg')
img
# Out:
# <PIL.Image.Image image mode=RGBA size=624x624 at 0x7FE3CF1951C0>

# %%
df.columns
# Out:
# Index(['Name', 'Wikidata-Q-ID', 'Wikipedia-URL', 'URL-names', 'Summary',
#        'Wikipedia-json', 'image', 'thumbnail', 'birth', 'death',
#        'timeline_position', 'VIAF', 'wikidata', 'MET Object Indices',
#        'REAL MET Object IDS'],
#       dtype='object')

# %% [markdown]
# ## open all URLs and save the squared images names [artist-index]_[image-index].png

# %%
# open all the URLs and save the squared images names [artist-index]_[image-index].png

count = 0

# iterate over artists
for i in range(len(df)):
    
    if new_df['URL-Liste-small'][i] == ['nan']:
        count += 1
        print(count)
        continue
    
    else:
        
        index = 0
        # iterate over list of urls
        for j in new_df['URL-Liste-small'][i]:
    
            if j == 'nan':
                index += 1
                continue
            elif j == '':
                index += 1
                continue
            else:
                img = getsquared_image(j.replace(' ', '%20'))
                filename = './thumbnails/MET/' + str(i) + '_' + str(index) + '.png'
                img.save(filename, 'PNG')
                index += 1
        
        print(count)
        count += 1

# %%
# test with one file 
# open thumbnail, get width, height

img = Image.open(urlopen(new_df['URL-Liste-small'][8][0]))
width, height = img.size

# store the bigger one in s

if width < height:
    s = height
else:
    s = width
s

# create empty Image file in thumbnail size squared
index = '008'

new_img = Image.new('RGB', (s, s))

new_img.paste(img, (0, 0))
#new_img.save('./thumbnails/cables/thumbnail_' + index + '.jpg')
new_img
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-48f6e8f533d7> in <module>
#       2 # open thumbnail, get width, height
#       3
# ----> 4 img = Image.open(urlopen(new_df['URL-Liste-small'][8][0]))
#       5 width, height = img.size
#       6
#
# NameError: name 'new_df' is not defined

# %%
df
# Out:
#                                        Name Wikidata-Q-ID  \
# 0                                   Cimabue        Q15790
# 1                           Arnolfo di Lapo       Q315249
# 2                                   Bonanno       Q892084
# 3                             Nicola Pisano       Q364413
# 4                           Giovanni Pisano       Q314932
# ..                                      ...           ...
# 287                               Dono Doni       Q714914
# 288                           Cesare Nebbia       Q503575
# 289  Niccolò Circignani detto il Pomarancio       Q382762
# 290                                Bronzino         Q7803
# 291                          Giorgio Vasari       Q128027
#
#                                          Wikipedia-URL  \
# 0                https://en.wikipedia.org/wiki/Cimabue
# 1      https://en.wikipedia.org/wiki/Arnolfo_di_Cambio
# 2         https://en.wikipedia.org/wiki/Bonanno_Pisano
# 3          https://en.wikipedia.org/wiki/Nicola_Pisano
# 4        https://en.wikipedia.org/wiki/Giovanni_Pisano
# ..                                                 ...
# 287            https://en.wikipedia.org/wiki/Dono_Doni
# 288        https://en.wikipedia.org/wiki/Cesare_Nebbia
# 289  https://en.wikipedia.org/wiki/Niccol%C3%B2_Cir...
# 290             https://en.wikipedia.org/wiki/Bronzino
# 291       https://en.wikipedia.org/wiki/Giorgio_Vasari
#
#                    URL-names  \
# 0                    Cimabue
# 1          Arnolfo_di_Cambio
# 2             Bonanno_Pisano
# 3              Nicola_Pisano
# 4            Giovanni_Pisano
# ..                       ...
# 287                Dono_Doni
# 288            Cesare_Nebbia
# 289  Niccol%C3%B2_Circignani
# 290                 Bronzino
# 291           Giorgio_Vasari
#
#                                                Summary  \
# 0    Cimabue, also known as Cenni di Pepo or Cenni ...
# 1    Arnolfo di Cambio was an Italian architect and...
# 2    Bonanno Pisano (Pisa), active in the 1170s and...
# 3    Nicola Pisano was an Italian sculptor whose wo...
# 4    Giovanni Pisano was an Italian sculptor, paint...
# ..                                                 ...
# 287  Dono Doni, also known as Adone Doni or Dono de...
# 288  Cesare Nebbia (c.1536–c.1622) was an Italian p...
# 289  Niccolò Circignani was an Italian painter of t...
# 290  Agnolo di Cosimo, usually known as Bronzino or...
# 291  Giorgio Vasari was an Italian painter, archite...
#
#                                         Wikipedia-json  \
# 0    {'type': 'standard', 'title': 'Cimabue', 'disp...
# 1    {'type': 'standard', 'title': 'Arnolfo di Camb...
# 2    {'type': 'standard', 'title': 'Bonanno Pisano'...
# 3    {'type': 'standard', 'title': 'Nicola Pisano',...
# 4    {'type': 'standard', 'title': 'Giovanni Pisano...
# ..                                                 ...
# 287  {'type': 'standard', 'title': 'Dono Doni', 'di...
# 288  {'type': 'standard', 'title': 'Cesare Nebbia',...
# 289  {'type': 'standard', 'title': 'Niccolò Circign...
# 290  {'type': 'standard', 'title': 'Bronzino', 'dis...
# 291  {'type': 'standard', 'title': 'Giorgio Vasari'...
#
#                                                  image  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 287  https://upload.wikimedia.org/wikipedia/commons...
# 288  https://upload.wikimedia.org/wikipedia/commons...
# 289  https://upload.wikimedia.org/wikipedia/commons...
# 290  https://upload.wikimedia.org/wikipedia/commons...
# 291  https://upload.wikimedia.org/wikipedia/commons...
#
#                                              thumbnail  birth  death  \
# 0    https://upload.wikimedia.org/wikipedia/commons...   1240   1302
# 1    https://upload.wikimedia.org/wikipedia/commons...   1240   1302
# 2    https://upload.wikimedia.org/wikipedia/commons...   9999   9999
# 3    https://upload.wikimedia.org/wikipedia/commons...   1225   1284
# 4    https://upload.wikimedia.org/wikipedia/commons...   1248   1316
# ..                                                 ...    ...    ...
# 287  https://upload.wikimedia.org/wikipedia/commons...   1500   1575
# 288  https://upload.wikimedia.org/wikipedia/commons...   1536   1614
# 289  https://upload.wikimedia.org/wikipedia/commons...   1517   1597
# 290  https://upload.wikimedia.org/wikipedia/commons...   1503   1572
# 291  https://upload.wikimedia.org/wikipedia/commons...   1511   1574
#
#      timeline_position       VIAF                               wikidata  \
# 0                 1271   11146779   https://www.wikidata.org/wiki/Q15790
# 1                 1271  265308757  https://www.wikidata.org/wiki/Q315249
# 2                 9999   95743493  https://www.wikidata.org/wiki/Q892084
# 3                 1254   79399625  https://www.wikidata.org/wiki/Q364413
# 4                 1282  100174152  https://www.wikidata.org/wiki/Q314932
# ..                 ...        ...                                    ...
# 287               1538   74702895  https://www.wikidata.org/wiki/Q714914
# 288               1575   13152008  https://www.wikidata.org/wiki/Q503575
# 289               1557   95809921  https://www.wikidata.org/wiki/Q382762
# 290               1538   59354048    https://www.wikidata.org/wiki/Q7803
# 291               1542   46768219  https://www.wikidata.org/wiki/Q128027
#
#                                     MET Object Indices  \
# 0                                                  nan
# 1                                                  nan
# 2                                                  nan
# 3                                                  nan
# 4                     [313456, 313457, 315423, 315800]
# ..                                                 ...
# 287                                                nan
# 288  [209395, 209639, 209640, 209658, 209659, 21035...
# 289                                           [211022]
# 290   [213792, 238232, 239821, 295526, 295527, 376242]
# 291                                                nan
#
#                                    REAL MET Object IDS  \
# 0                                                  nan
# 1                                                  nan
# 2                                                  nan
# 3                                                  nan
# 4                     [463414, 463415, 465937, 466326]
# ..                                                 ...
# 287                                                nan
# 288  [340591, 340835, 340836, 340854, 340855, 34157...
# 289                                           [342245]
# 290   [345085, 370424, 372062, 435802, 435803, 643060]
# 291                                                nan
#
#                                        URL-Liste-small
# 0                                                [nan]
# 1                                                [nan]
# 2                                                [nan]
# 3                                                [nan]
# 4    [https://images.metmuseum.org/CRDImages/md/web...
# ..                                                 ...
# 287                                              [nan]
# 288  [https://images.metmuseum.org/CRDImages/dp/web...
# 289  [https://images.metmuseum.org/CRDImages/dp/web...
# 290  [https://images.metmuseum.org/CRDImages/dp/web...
# 291                                              [nan]
#
# [292 rows x 16 columns]

# %%
len(liste)
# Out:
# 292

# %%
df.columns
# Out:
# Index(['Name', 'Wikidata-Q-ID', 'Wikipedia-URL', 'URL-names', 'Summary',
#        'Wikipedia-json', 'image', 'thumbnail', 'birth', 'death',
#        'timeline_position', 'VIAF', 'wikidata', 'MET Object Indices',
#        'REAL MET Object IDS', 'URL-Liste-small'],
#       dtype='object')

# %% [markdown]
# # SAVE df as csv

# %%
filename = 'artist_qid.csv'
df.to_csv(filename, index = False, header=True)
